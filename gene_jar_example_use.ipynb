# %%
from pathlib import Path

import pandas as pd

from gene_jar import GeneJar, MatchType

# %%
# Define data directory
DATA_DIR = Path("/Users/rsaxs014/Desktop/gene-jar/src/gene_jar/data")

# List of (dict key, filename) pairs
files = [
    ("primary_df", "summary_df.h5"),
    ("ortholog_df", "ortholog_match_subset_genes_df.h5"),
    ("flj_clone_df", "flj_clone_symbol_match_subset_genes_df.h5"),
    ("disease_df", "disease_prefix_match_subset_genes_df.h5"),
    ("hgnc_gene_group_df", "gene_group_prefix_match_subset_genes_df.h5"),
    ("gene_id_df", "gene_id_match_subset_genes_df.h5"),
    ("mgi_withdrawn_df", "mgi_withdrawn_symbol_match_subset_genes_df.h5"),
    ("ncbi_gene_group_df", "ncbi_gene_group_symbol_match_subset_genes_df.h5"),
    (
        "ncbi_gene_interaction_df",
        "ncbi_gene_interaction_symbol_match_subset_genes_df.h5",
    ),
    ("ncbi_gene_neighbor_df", "ncbi_gene_neighbor_match_subset_genes_df.h5"),
    ("placeholder_df", "placeholder_match_subset_genes_df.h5"),
    ("previous_df", "previous_symbol_match_subset_genes_df.h5"),
    ("protein_mass_df", "protein_mass_match_subset_genes_df.h5"),
]

# Load all DataFrames into a dictionary
dfs = {key: pd.read_hdf(DATA_DIR / filename, key="df") for key, filename in files}

# Create the resolver
gj = GeneJar(**dfs)

# %%
# search primary dataframe
rows_primary = gj.resolve(symbol="KRAS")
rows_primary
# Out:
#            HGNC_ID            ENSG_ID         NCBI_ID primary_gene_symbol  \
# 53678  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53679  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53680  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53681  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53682  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53683  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53684  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53685  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53686  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53687  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53688  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53689  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53690  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53691  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53692  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53693  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53694  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53695  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53696  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53697  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 53698  {HGNC:6407}  {ENSG00000133703}  {GENE ID:3845}                KRAS
# 81133  {HGNC:7989}  {ENSG00000213281}  {GENE ID:4893}                NRAS
#
#       gene_symbol captured                           captured as:
# 53678    'C-K-RAS        F                                    NaN
# 53679     C-K-RAS        F                                    NaN
# 53680        CFC2        T                Prefix Condition Symbol
# 53681     K-RAS2A        F                                    NaN
# 53682     K-RAS2B        F                                    NaN
# 53683     K-RAS4A        F                                    NaN
# 53684     K-RAS4B        F                                    NaN
# 53685       K-Ras        F                                    NaN
# 53686     K-Ras 2        F                                    NaN
# 53687     K-Ras4B        F                                    NaN
# 53688      KI-RAS        F                                    NaN
# 53689        KRAS        T                    Primary Gene Symbol
# 53690       KRAS1        F                                    NaN
# 53691       KRAS2        T  Previous Symbol, Withdrawn MGI Symbol
# 53692          NS        F                                    NaN
# 53693         NS3        T                Prefix Condition Symbol
# 53694         OES        T                Prefix Condition Symbol
# 53695        RALD        T                Prefix Condition Symbol
# 53696       RASK2        T               Prefix Gene Group Symbol
# 53697    c-Ki-ras        F                                    NaN
# 53698   c-Ki-ras2        F                                    NaN
# 81133        KRAS        T                        Ortholog Symbol

# %%
rows_primary = gj.resolve(symbol="KRAS", match_type=MatchType.PARTIAL)
rows_primary
# Out:
#             HGNC_ID            ENSG_ID           NCBI_ID primary_gene_symbol  \
# 53678   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53679   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53680   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53681   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53682   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53683   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53684   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53685   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53686   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53687   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53688   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53689   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53690   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53691   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53692   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53693   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53694   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53695   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53696   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53697   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53698   {HGNC:6407}  {ENSG00000133703}    {GENE ID:3845}                KRAS
# 53699   {HGNC:6406}  {ENSG00000220635}    {GENE ID:3844}              KRASP1
# 53700   {HGNC:6406}  {ENSG00000220635}    {GENE ID:3844}              KRASP1
# 53701   {HGNC:6406}                 {}    {GENE ID:3844}              KRASP1
# 77847  {HGNC:25121}  {ENSG00000270170}  {GENE ID:152217}            NCBP2AS2
# 81133   {HGNC:7989}  {ENSG00000213281}    {GENE ID:4893}                NRAS
#
#       gene_symbol captured                           captured as:
# 53678    'C-K-RAS        F                                    NaN
# 53679     C-K-RAS        F                                    NaN
# 53680        CFC2        T                Prefix Condition Symbol
# 53681     K-RAS2A        F                                    NaN
# 53682     K-RAS2B        F                                    NaN
# 53683     K-RAS4A        F                                    NaN
# 53684     K-RAS4B        F                                    NaN
# 53685       K-Ras        F                                    NaN
# 53686     K-Ras 2        F                                    NaN
# 53687     K-Ras4B        F                                    NaN
# 53688      KI-RAS        F                                    NaN
# 53689        KRAS        T                    Primary Gene Symbol
# 53690       KRAS1        F                                    NaN
# 53691       KRAS2        T  Previous Symbol, Withdrawn MGI Symbol
# 53692          NS        F                                    NaN
# 53693         NS3        T                Prefix Condition Symbol
# 53694         OES        T                Prefix Condition Symbol
# 53695        RALD        T                Prefix Condition Symbol
# 53696       RASK2        T               Prefix Gene Group Symbol
# 53697    c-Ki-ras        F                                    NaN
# 53698   c-Ki-ras2        F                                    NaN
# 53699      KRAS1P        T                        Previous Symbol
# 53700      KRASP1        T                    Primary Gene Symbol
# 53701     c-Kras1        F                                    NaN
# 77847      KRASIM        F                                    NaN
# 81133        KRAS        T                        Ortholog Symbol

# %%
gj.resolve(symbol="KRAS", symbol_category="Prefix Condition Symbol")
# Out:
#       primary_gene_symbol alias_symbol      HGNC_ID            ENSG_ID  \
# 46106                KRAS         CFC2  {HGNC:6407}  {ENSG00000133703}
# 46118                KRAS          NS3  {HGNC:6407}  {ENSG00000133703}
# 46119                KRAS          OES  {HGNC:6407}  {ENSG00000133703}
# 46120                KRAS         RALD  {HGNC:6407}  {ENSG00000133703}
#
#               NCBI_ID  Prefix Disease Symbol Match Matching Phenotype Symbol
# 46106  {GENE ID:3845}                         True                      CFC2
# 46118  {GENE ID:3845}                         True                       NS3
# 46119  {GENE ID:3845}                         True                       OES
# 46120  {GENE ID:3845}                         True                      RALD

# %%
gj.symbol_categories()
# Out:
# ['Clone Symbol',
#  'Gene Group Symbol',
#  'Gene Identifier Symbol',
#  'Gene Interaction Symbol',
#  'Gene Neighbor Symbol',
#  'Ortholog Symbol',
#  'Placeholder Symbol',
#  'Prefix Condition Symbol',
#  'Prefix Gene Group Symbol',
#  'Previous Symbol',
#  'Primary',
#  'Protein Mass Symbol',
#  'Withdrawn MGI Symbol']

# %%
result = gj.ambiguity_check("ABL")

result.ambiguous
# Out:
# True

# %%
result.primary_gene_symbol
# Out:
# ['ABL1', 'DSP-AS1', 'MTTP']

# %%
print(result.hgnc_id)
print(result.ncbi_id)
print(result.ensg_id)
# Out:
# ['HGNC:76', 'HGNC:56039', 'HGNC:7467']
# ['GENE ID:25', 'GENE ID:101928076', 'GENE ID:4547']
# ['ENSG00000097007', 'ENSG00000261189', 'ENSG00000138823']
