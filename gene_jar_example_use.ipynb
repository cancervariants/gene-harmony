# %%
from pathlib import Path

import pandas as pd

from gene_jar import GeneJar, MatchType

# %%
# Define data directory
DATA_DIR = Path("/Users/rsaxs014/Desktop/gene-jar/src/gene_jar/data")

# List of (dict key, filename) pairs
files = [
    ("primary_df", "summary_df.h5"),
    ("ortholog_df", "ortholog_match_subset_genes_df.h5"),
    ("flj_clone_df", "flj_clone_symbol_match_subset_genes_df.h5"),
    ("phenotype_df", "phenotype_match_subset_genes_df.h5"),
    ("hgnc_gene_group_df", "gene_group_prefix_match_subset_genes_df.h5"),
    ("gene_id_df", "gene_id_match_subset_genes_df.h5"),
    ("mgi_withdrawn_df", "mgi_withdrawn_symbol_match_subset_genes_df.h5"),
    ("ncbi_related_gene_df", "ncbi_related_gene_match_subset_genes_df.h5"),
    (
        "ncbi_gene_interaction_df",
        "ncbi_gene_interaction_symbol_match_subset_genes_df.h5",
    ),
    ("ncbi_gene_neighbor_df", "ncbi_gene_neighbor_match_subset_genes_df.h5"),
    ("placeholder_df", "placeholder_match_subset_genes_df.h5"),
    ("previous_df", "previous_symbol_match_subset_genes_df.h5"),
    ("protein_mass_df", "protein_mass_match_subset_genes_df.h5"),
    ("alternate_abbreviation_df", "alt_abbrev_symbol_match_subset_genes_df.h5"),
]

# Load all DataFrames into a dictionary
dfs = {key: pd.read_hdf(DATA_DIR / filename, key="df") for key, filename in files}

# Create the resolver
gj = GeneJar(**dfs)

# %%
gj.resolve("KRAS")
# Out:
#    candidate_rank primary_gene_symbol      HGNC_ID         NCBI_ID  \
# 0               1                KRAS  {HGNC:6407}  {GENE ID:3845}
# 1               2                NRAS  {HGNC:7989}  {GENE ID:4893}
#
#              ENSG_ID        best_category  \
# 0  {ENSG00000133703}  Primary Gene Symbol
# 1  {ENSG00000213281}      Ortholog Symbol
#
#                                            qualifier matched_symbol  \
# 0                                                 {}         {KRAS}
# 1  {'Matching Species': ['Norway rat - BN/NHsdMcw...         {KRAS}
#
#       matched_categories  relationship_count
# 0  [Primary Gene Symbol]                   1
# 1      [Ortholog Symbol]                   1

# %%
rows_primary = gj.resolve(symbol="KRAS", match_type=MatchType.PARTIAL)
rows_primary
# Out:
#    candidate_rank primary_gene_symbol                     HGNC_ID  \
# 0               1                KRAS  {HGNC:6407, {'HGNC:6407'}}
# 1               2              KRASP1  {HGNC:6406, {'HGNC:6406'}}
# 2               3                NRAS                 {HGNC:7989}
#
#                             NCBI_ID  \
# 0  {{'GENE ID:3845'}, GENE ID:3845}
# 1  {{'GENE ID:3844'}, GENE ID:3844}
# 2                    {GENE ID:4893}
#
#                                          ENSG_ID        best_category  \
# 0         {ENSG00000133703, {'ENSG00000133703'}}  Primary Gene Symbol
# 1  {ENSG00000220635, {'ENSG00000220635'}, set()}  Primary Gene Symbol
# 2                              {ENSG00000213281}      Ortholog Symbol
#
#                                            qualifier  \
# 0                                                 {}
# 1                                                 {}
# 2  {'Matching Species': ['Norway rat - BN/NHsdMcw...
#
#               matched_symbol  \
# 0              {KRAS, KRAS2}
# 1  {KRAS1P, KRASP1, c-Kras1}
# 2                     {KRAS}
#
#                                   matched_categories  relationship_count
# 0  [Primary Gene Symbol, Previous Symbol, Alterna...                   4
# 1  [Primary Gene Symbol, Previous Symbol, Alterna...                   3
# 2                                  [Ortholog Symbol]                   1

# %%
gj.resolve("ABL")
# Out:
#    candidate_rank primary_gene_symbol      HGNC_ID         NCBI_ID  \
# 0               1                ABL1    {HGNC:76}    {GENE ID:25}
# 1               2                MTTP  {HGNC:7467}  {GENE ID:4547}
#
#              ENSG_ID     best_category                             qualifier  \
# 0  {ENSG00000097007}   Previous Symbol    {'Previous Symbol Source': 'HGNC'}
# 1  {ENSG00000138823}  Phenotype Symbol  {'Matching Phenotype Symbol': 'ABL'}
#
#   matched_symbol                    matched_categories  relationship_count
# 0          {ABL}  [Previous Symbol, Gene Group Symbol]                   2
# 1          {ABL}                    [Phenotype Symbol]                   1

# %%
result = gj.ambiguity_check("ABL")

result.is_ambiguous
# Out:
# True

# %%
result
# Out:
# AmbiguityResult(is_ambiguous=True, gene_matches=[GeneMatch(primary_gene_symbol='ABL1', hgnc_id={'HGNC:76'}, ncbi_id={'GENE ID:25'}, ensg_id={'ENSG00000097007'}), GeneMatch(primary_gene_symbol='MTTP', hgnc_id={'HGNC:7467'}, ncbi_id={'GENE ID:4547'}, ensg_id={'ENSG00000138823'})])

# %%
result.gene_matches
# Out:
# [GeneMatch(primary_gene_symbol='ABL1', hgnc_id={'HGNC:76'}, ncbi_id={'GENE ID:25'}, ensg_id={'ENSG00000097007'}),
#  GeneMatch(primary_gene_symbol='MTTP', hgnc_id={'HGNC:7467'}, ncbi_id={'GENE ID:4547'}, ensg_id={'ENSG00000138823'})]

# %%
result.gene_matches[0].primary_gene_symbol
# Out:
# 'ABL1'

# %%
result.gene_matches[0].hgnc_id
# Out:
# {'HGNC:76'}

# %%
result.gene_matches[0].ncbi_id
# Out:
# {'GENE ID:25'}

# %%
result.gene_matches[0].ensg_id
# Out:
# {'ENSG00000097007'}
